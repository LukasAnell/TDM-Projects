# %% [markdown]
# # Project 1 -- Lukas Anell

# %%
# /anvil/projects/tdm/data/movies_and_tv/rotten_tomatoes_movies.csv

# %% [markdown]
# ## Question 1

# %%
import pandas as pd


myDF = pd.read_csv("/anvil/projects/tdm/data/movies_and_tv/rotten_tomatoes_movies.csv")

# %%
myDF.head()
# Out:
#                      rotten_tomatoes_link  \
# 0                              /m/0814255
# 1                              /m/0878835
# 2                                   /m/10
# 3                 /m/1000013-12_angry_men
# 4  /m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  A teenager discovers he's the descendant of a ...
# 1  Kate has a lot on her mind. There's the ethics...
# 2  Blake Edwards' 10 stars Dudley Moore as George...
# 3  A Puerto Rican youth is on trial for murder, a...
# 4  This 1954 Disney version of Jules Verne's 20,0...
#
#                                    critics_consensus  \
# ...

# %%
myDF.tail()
# Out:
#       rotten_tomatoes_link      movie_title  \
# 16633         /m/zoot_suit        Zoot Suit
# 16634          /m/zootopia         Zootopia
# 16635   /m/zorba_the_greek  Zorba the Greek
# 16636              /m/zulu             Zulu
# 16637         /m/zulu_dawn        Zulu Dawn
#
#                                               movie_info  \
# 16633  Based on a 1940s Los Angeles murder trial, thi...
# 16634  The modern mammal metropolis of Zootopia is a ...
# 16635  If ever there was a role that Anthony Quinn wa...
# 16636  Filmed on a grand scale, Zulu is a rousing rec...
# 16637  A prequel to Zulu, Zulu Dawn depicts the event...
#
#                                        critics_consensus  \
# 16633                                                NaN
# 16634  The brilliantly well-rounded Zootopia offers a...
# 16635                                                NaN
# 16636                                                NaN
# 16637                                                NaN
#
# ...

# %%
myDF.shape
# Out:
# (16638, 23)

# %%
my_rating_counts = myDF['rating'].value_counts()

# %%
import matplotlib.pyplot as plt

plt.plot(my_rating_counts, color="#78b159")
plt.title("Counts of Each Rating Type")
plt.xlabel("Rating Type")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# For the plot, I was confused for a bit because I was under the impression title, xlabel, and ylabel would be arguments within `plot()`, but it wouldn't work. So I looked at the matplotlib docs for `plot()` and found out that they're separate functions you call. Then, I tried to use `color` as a function but it didn't work, and I found out that that one is in fact an argument. Very confusing.

# %% [markdown]
# ## Question 2

# %%
director_counts = myDF['directors'].value_counts(sort=True, ascending=True)

# %%
len(my_rating_counts)
# Out:
# 8

# %%
len(director_counts)
# Out:
# 8314

# %%
studio_name_counts = myDF['studio_name'].value_counts(sort=True, ascending=True)

# %%
len(studio_name_counts)
# Out:
# 2886

# %%
director_counts.head()
# Out:
# directors
# Vincente Minnelli, Lemuel Ayers, Charles Walters, Roy Del Ruth, George Sidney, Robert Lewis, Norman Taurog    1
# Martin Curland                                                                                                1
# Talya Lavie                                                                                                   1
# Katie Graham, Andrew Matthews                                                                                 1
# Tariq Tapa                                                                                                    1
# Name: count, dtype: int64

# %%
director_counts.tail()
# Out:
# directors
# Sidney Lumet        30
# Steven Spielberg    32
# Clint Eastwood      35
# Alfred Hitchcock    36
# Woody Allen         36
# Name: count, dtype: int64

# %%
studio_name_counts.head()
# Out:
# studio_name
# Zentropa Productions          1
# Gravity Pictures              1
# Sherwood                      1
# Echolands Creative Group      1
# Deutsche Universum Film AG    1
# Name: count, dtype: int64

# %%
studio_name_counts.tail()
# Out:
# studio_name
# IFC Films                398
# 20th Century Fox         414
# Universal Pictures       469
# Warner Bros. Pictures    492
# Paramount Pictures       497
# Name: count, dtype: int64

# %% [markdown]
# Not sure what I can add to this. Pretty straightforward.
#
# 2.1: See above.
#
# 2.2: Alfred Hitchcock and Woody Allen are tied for the most projects directed.
#
# 2.3: Paramount Pictures has produced the most films.

# %% [markdown]
# ## Question 3

# %%
myDF[myDF['genre'] == "Comedy"].head()
# Out:
#                        rotten_tomatoes_link           movie_title  \
# 1                                /m/0878835           Please Give
# 23                    /m/10004050-bandwagon             Bandwagon
# 27  /m/10004232-10004232-tale_of_two_pizzas  A Tale of Two Pizzas
# 29           /m/10004352-going_the_distance    Going the Distance
# 53                              /m/10006270       When Do We Eat?
#
#                                            movie_info  \
# 1   Kate has a lot on her mind. There's the ethics...
# 23  A group of hard-working, young North Carolinia...
# 27  Two warring families are brought together by l...
# 29  Delightfully raunchy wit drives this teen come...
# 53  This is the story of the world's fastest Passo...
#
#                                     critics_consensus  \
# 1   Nicole Holofcener's newest might seem slight i...
# 23                                                NaN
# 27                                                NaN
# ...

# %%
len(myDF[myDF['genre'] == "Comedy"])
# Out:
# 1202

# %%
myDF['genre'].str.contains("Comedy").sum()
# Out:
# 5385

# %%
myDF['genre'].str.contains("Romance").sum()
# Out:
# 1807

# %% [markdown]
# At first I thought using `.str.contains()` would have the same syntax as using `==`, but it makes sense that it doesn't. I'm curious if these behave as lists, and if so can list comprehension be used?
#
# 3.1: 1202 rows
#
# 3.2: 5385 rows
#
# 3.3: 1807 rows

# %% [markdown]
# ## Question 4

# %%
myDF.loc[myDF['rating'] == 'R)', 'rating'] = 'R'
myDF.loc[myDF['rating'] == 'PG-13)', 'rating'] = 'PG-13'

# %%
rating_counts = myDF['rating'].value_counts()
rating_counts
# Out:
# rating
# R        6137
# NR       4862
# PG-13    2888
# PG       2062
# G         652
# NC17       37
# Name: count, dtype: int64

# %%
tomatometer_counts = myDF['tomatometer_status'].value_counts()
tomatometer_counts
# Out:
# tomatometer_status
# Rotten             7233
# Fresh              6448
# Certified Fresh    2957
# Name: count, dtype: int64

# %%
import pandas as pd


table_data = pd.crosstab(myDF['rating'], myDF['tomatometer_status'])
table_data
# Out:
# tomatometer_status  Certified Fresh  Fresh  Rotten
# rating
# G                               124    336     192
# NC17                              7     19      11
# NR                              576   3081    1205
# PG                              376    753     933
# PG-13                           563    593    1732
# R                              1311   1666    3160

# %% [markdown]
# The crosstab function is super cool, that definitely seems useful. Is it possible to do it with more than 2 dimensions? Not that it would be very easy to visualize, but I'm curious if it's a thing.
#
# 4.1: See above.
#
# 4.2: Rotten was given to the most films.
#
# 4.3: See above.

# %% [markdown]
# ## Question 5

# %%
myDF['joined_reviews'] = myDF['rating'] + " " + myDF['tomatometer_status']
myDF['joined_reviews'].tail()
# Out:
# 16633              R Rotten
# 16634    PG Certified Fresh
# 16635              NR Fresh
# 16636              PG Fresh
# 16637             PG Rotten
# Name: joined_reviews, dtype: object

# %%
subset_df = myDF[(myDF["rating"] == "PG") & (myDF["tomatometer_status"] == "Certified Fresh")]
subset_df.head()
# Out:
#                     rotten_tomatoes_link                   movie_title  \
# 20   /m/1000355-adventures_of_robin_hood  The Adventures of Robin Hood
# 52              /m/1000626-all_about_eve                 All About Eve
# 94                /m/10008507-deep_water                    Deep Water
# 134             /m/10009001-the_freshman                  The Freshman
# 307                 /m/1002352-big_sleep                 The Big Sleep
#
#                                             movie_info  \
# 20   In order to avoid the material copyrighted by ...
# 52   Based on the story The Wisdom of Eve by Mary O...
# 94   Co-directors Louise Osmond and Jerry Rothwell'...
# 134  This is the story of a college freshman so eag...
# 307  The definitive Humphrey Bogart/Lauren Bacall v...
#
#                                      critics_consensus  \
# 20   Errol Flynn thrills as the legendary title cha...
# 52   Smart, sophisticated, and devastatingly funny,...
# ...

# %%
myDF[myDF["movie_title"] == "Cars"]
# Out:
#      rotten_tomatoes_link movie_title  \
# 4118              /m/cars        Cars
#
#                                              movie_info  \
# 4118  Lightning McQueen, a hotshot rookie race car d...
#
#                                       critics_consensus  \
# 4118  Cars offers visual treats that more than compe...
#
#                                        poster_image_url rating  \
# 4118  https://resizing.flixster.com/UJMEfnjBwgLRtUij...      G
#
#                                                   genre  \
# 4118  Action & Adventure, Animation, Comedy, Kids & ...
#
#                      directors  \
# 4118  John Lasseter, Joe Ranft
#
#                                                 writers  \
# 4118  John Lasseter, Dan Fogelman, Joe Ranft, Kiel M...
#
#                                                    cast  ...  \
# 4118  Owen Wilson, Paul Newman, Bonnie Hunt, Larry T...  ...
#
#      tomatometer_status tomatometer_rating  tomatometer_count audience_status  \
# ...

# %%
myDF[myDF["movie_title"] == "Interstellar"]
# Out:
#       rotten_tomatoes_link   movie_title  \
# 7948  /m/interstellar_2014  Interstellar
#
#                                              movie_info  \
# 7948  With our time on Earth coming to an end, a tea...
#
#                                       critics_consensus  \
# 7948  Interstellar represents more of the thrilling,...
#
#                                        poster_image_url rating  \
# 7948  https://resizing.flixster.com/wPllQbE6ho1sxFzN...  PG-13
#
#                                               genre          directors  \
# 7948  Action & Adventure, Science Fiction & Fantasy  Christopher Nolan
#
#                                 writers  \
# 7948  Christopher Nolan, Jonathan Nolan
#
#                                                    cast  ...  \
# 7948  Matthew McConaughey, Anne Hathaway, Jessica Ch...  ...
#
#      tomatometer_status tomatometer_rating  tomatometer_count audience_status  \
# ...

# %% [markdown]
# 5.1: PG Rotten has the most counts
#
# 5.2: See above.
#
# 5.3: See above.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
#
# https://www.purdue.edu/odos/osrr/honor-pledge/
