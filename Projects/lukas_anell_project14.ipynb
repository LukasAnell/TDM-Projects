# %% [markdown]
# # Project 14 -- Lukas Anell

# %% [markdown]
# ## Question 1

# %% [markdown]
# In The Data Mine, I found that I enjoy learning R a lot. Being able to quickly see results and visualizing the data I work with is nice, and I like how simple it can be sometimes. Even when I don't know something, R documentation is always super helpful and I've learned so much just from using Google and finding documentation for a certain function. I feel like this class has been huge in helping me be more prepared for my future when I'll probably be using R a lot as a Data Science major. I wish there were more opportunities to work with others in this class, outside of just office hours with the TAs and my roommate, but I know future classes have that so I'm looking forward to taking more advanced Data Mine classes.

# %% [markdown]
# ## Question 2

# %% [markdown]
# I think the class should be more oriented around teamwork, like having opportunities for group projects. I'm sure it would be difficult given that the class is asynchronous, but I think it would help a lot with motivation and learning experience.

# %% [markdown]
# ## Question 3

# %% [markdown]
# As a Data Science major, I think I'd struggle with finding direction for my early learning with topics in data science, and I think the Data Mine has helped me think more about how and what I need to learn to reach my future goals.

# %% [markdown]
# ## Question 4

# %% [markdown]
# No additional feedback.

# %% [markdown]
# ## Question 5

# %% [markdown]
# - Data/line fitting. We covered a little bit but I think this is important.
# - More statistics/math. I think it would be useful in understanding some of the data we work with, and how to present it effectively.
# - More advanced data parsing. All of the data we worked with was very structured and neat, so I think learning how to deal with more messy datasets would be useful in the future.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
#
# https://www.purdue.edu/odos/osrr/honor-pledge/
